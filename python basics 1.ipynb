# %% [markdown]
# # Python Basics

# %% [markdown]
# 1.What is Python, and why is it popular?
#
#   python is aprogramming language with a set of special rules, keywords and symbols for instruction to computer language.
#
# 2.What is an interpreter in Python?
#
#   An interpreter in python is a program that reads and execute code line by line.
#
# 3.What are pre-defined keywords in Python?
#
#   predefined are words that hold a special meaning and have specific purpose.
#
# 4.Can keywords be used as variable names?
#
#   No, keywords cannot be used as variable name caz keywords are reserved word that have predefined meaning and part of the syntax and if we do it will throw an error.
#
# 5.What is mutability in Python?
#
#   Objects/containers whose state or value can be changed after they are created or called as mutable objects or container, also called as assignment.
#
# 6.Why are lists mutable, but tuples are immutable?
#
#   Because lists are intended for collection of items that can change over time and we can add remove, or modify elements pf a list after its created.
#   and Tuples are immutable because tuples are designed to represent fixed collections of items where immutability ensures data integirity.
#
# 7.What is the difference between “==” and “is” operators in Python?
#
#   "==" it compares values of two objects to see if they are equal or not.
#   and "is" compares the identity of two objects to see if they refer to thge same object in memory.
#
# 8.What are logical operators in Python?
#
#   lohical operators are use to combine conditional statements and evaluyate the values whether it is true or not
#
# 9.What is type casting in Python?
#
#   the prrocess of changimg the data type of a value/object is known as Type cassting.
#   for. eg. str into float and float into str.
#
# 10.What is the difference between implicit and explicit type casting?
#    implict is a type casting that python understand t5he data type.
#
#    In, implict type casting python undertsand the data type. it basically do calculations.
#    and in explicit it basically to conversion.
#
# 11.What is the purpose of conditional statements in Python?
#    the purpose of conditional ststements in python is to make certain decisionson on conditions those conditional statement helps python to execute code true or false depends on condition that it is true or false.
#
# 12.How does the elif statement work?
#
#    the elif is a short word driven from else if, it allows us to check multiple conditions continously afte an if statement. if the statement is false, the programme moves on the elif condition and evaluates rhem in order.
#    how it works
#    if the statement is true the block of code will be executed and will skip all the rest.
#    if starement is false, it will moves toi another conditiuns until it finds a true conditions.
#    if non e of thr if and elif conditiond are true, the else block will be executed.
#
# 13.What is the difference between for and while loops?
#
#    while loops always allow to exceute a block of code rtepeatedly.
#    and for loop always apply and excute on a specific range or collections.
#
# 14.Describe a scenario where a while loop is more suitable than a for
#    loop?
#
#    Imagine we are building a program that asks the users to input a valid email address,. the program doesnt  know how many attempts the user need to provide a valid email. it should be keep askimg the user for input until they emter a valid email.
#    In this case, a while loo[ is more suitable, caz the number of attempts is not predetermined. the loop continues to run until the condition is met.
